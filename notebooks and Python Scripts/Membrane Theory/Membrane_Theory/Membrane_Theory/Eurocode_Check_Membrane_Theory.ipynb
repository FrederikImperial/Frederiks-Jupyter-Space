# %% [markdown]
# # Optimization of Wall Thickness of Cylindrical Cans with Membrane Theory
#
# - assume cylindrical shape and axisymmetric conditions and take stresses from membrane theory (Cl. 9.5.1 (1),(2))
# - Take Membrane Stresses from Annex C
# - Take Membrane Resistrance from Annex D

# %% [markdown]
# Investigate junction between can 114 and 115
#
# - Both have radius 2750
# - 114 (top) thickness 16mm
# - 115 (bottom) thickness 17mm

# %% [markdown]
# ## Loadcase 1:
# - V = 4 MN = 4E6 N
# - M = 33MNm = 33E 9 Nmm
# - Q = 1.76 MN = 1.76E6 N
# - Leverarm for Q: 33103 mm
#
# Application of Annex A delivers the following membrane stresses
#
# at $\theta = \pi$:
#
# from Uniform Axial Load
# $$ n_x = - \frac{F_x}{2\pi r} = - 4E6/(2\pi \cdot 2750) = -231.5 [N/mm]$$
#
# from Global Bending
# $$ n_{x,min} = - \frac{M}{\pi r^{2}} = -(33E9 + 1.76E6 \cdot 33103)/(\pi \cdot 2750^2) = - 3841.24 [N/mm]$$
#
# $$ \sum n_x = -4072.7[N/mm]$$
#
# at $\theta = \pi$:
#
# from Uniform Axial Load
# $$ n_x =-231.5 [N/mm]$$
#
# from Shear Force Q:
# $$ n_{x \theta,max} = \frac{V}{\pi r} = 1.76E6/(\pi \cdot 2750) = 203.72 [N/mm]$$
#
# ## Loadcase 2:
# ...

# %% [markdown]
# ## Buckling Resistances from Annex D
#
# L = 2368 mm <br>
# r = 2750 mm<br>
# t = 16 mm <br>
#
#
# ### relative Length Parameters
#
# $$ \omega = \frac{L}{\sqrt{rt}} = \frac{2368}{\sqrt{2750 \cdot 16}} = 11.29 $$
#
# $$ \Omega = \frac{t}{r}\omega = \frac{16}{2750}11.29 = 0.066$$
#
# ## Axial (meridional) compression
# ### Length domains
# $$ 1.7 \leq \omega \leq 1.43 \frac{r}{t} = 245.78 $$
# -> classified as medium length cylinder
# -> take $ C_x = 1$
#
# ### Critical axial buckling stress
# - assume BC1 or BC2 at both edges
#
# $$ \sigma_{x,Rcr} = 0.605EC_x \frac{t}{r} =  0.605 \cdot 200 000 \frac{16}{2750} = 704 [N/mm²]$$
#
# $$ \frac{r}{t} \leq \frac{1}{165}C_x\frac{E}{f_{yk}} $$
# $$ \frac{2750}{16} = 171.88 \not\leq \frac{1}{165}\frac{200000}{355} = 3.41 $$
# -> need to be checked against buckling
#
# ### Axial Compression buckling capacity parameters
#
# Take $ \bar{\lambda}_{x0}= 0.1$
#
# $$ \alpha_x = \alpha_{xG} \alpha_{xI} = 0.83 \cdot 0.426 = 0.354 $$
#
# with
#
# $$ \alpha_{xG} = 0.83 $$
# $$ \alpha_{xI} = \frac{1}{1+2.2(𝛿_0/t)^{0.75}} = \frac{1}{1+2.2 \cdot 0.52^{0.75}} = 0.426 $$
#
# - assume Value of axial compression fabrication quality parameter $Q_x$ = 25, corresponding to **Class B (High)**.
#
# $$ \frac{δ_0}{t} = \frac{1}{Q_x} \sqrt{\frac{r}{t}} = \frac{1}{25} \sqrt{\frac{2750}{16}} = 0.52$$
#
# plastic range factor
#
# $$ \beta_x = 1 - \frac{0.75}{1+1.1(𝛿_0/t)} = 1- \frac{0.75}{1+1.1 \cdot 0.52} = 0.52 $$
#
# interaction exponent
# $$ 𝜂_{x0} = 1.35 - 0.10(𝛿_0/t) = 1.35 - 0.1 \cdot 0.52 = 1.30 $$
#
# $$ 𝜂_{xp} = \frac{1}{0.45+0.72(𝛿_0/t)} = \frac{1}{0.45+0.72 \cdot 0.52} = 1.21 $$
#
# from Cl. 9.5.2 (3), (5)
#
# $$ \bar\lambda_x = \sqrt{f_{yk}/ \sigma_{x,Rcr}} = \sqrt{355/ 704} = 0.71 $$
#
# $$ \bar\lambda_{xp} = \sqrt{\frac{\alpha_x}{1- \beta_x}} = \sqrt{\frac{0.354}{1- 0.52}} = 0.86$$
#
# $$ 𝜂_x = [ \frac {\bar\lambda_x (𝜂_{xp}-𝜂_{x0})+ \bar\lambda_{xp} 𝜂_{x0}-\bar\lambda_{x0} 𝜂_{xp}}{\bar\lambda_{xp}-\bar\lambda_{x0}}] = [ \frac {0.71 (1.21-1.30)+ 0.86 \cdot 1.30-0.1 \cdot 1.21}{0.86-0.1}] =1.23$$
#
# Take $ 𝜒_{xh} = 1.10 $
#
# continue with Cl. 9.5.2 (4)
#
# $$ \chi = \chi_h - \frac{\bar\lambda}{ \bar\lambda_{0}} ( \chi_h - 1) = ... when \bar\lambda \leq \bar\lambda_0  $$
#
# $$ \chi = 1 - \beta \left(\frac{\bar{\lambda} - \bar{\lambda}_0}{\bar{\lambda}_p - \bar{\lambda}_0}\right)^{\eta} = 0.61 \quad \text{when} \quad \bar{\lambda}_0 < \bar{\lambda} < \bar{\lambda}_p $$
#
#
# $$ \chi = \frac{\alpha}{ \bar\lambda^2} = ... when \bar\lambda_p \leq \bar\lambda  $$
#
# continue with Cl. 9.5.2 (7), (8)
#
# $$ \sigma_{x,Rk} = \chi_x f_{yk} = 0.61 \cdot 355 = 216.55\quad \text{N/mm²} \quad  $$
#
# $$ \sigma_{x,Rd} = \chi_{x,Rk} / \gamma_{M1} = 216.55 /1.1 = 196.87\quad \text{N/mm²} \quad  $$
#
# $$ \sigma_{x,Rd} \cdot t = 196.87 \cdot 16 = 3149.9 \cancel{>} 4072.7 \quad \text{N/mm²} \quad \therefore \text{NOT OK!} \quad  $$
